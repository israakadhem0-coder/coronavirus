# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.13/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (2.32.4)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (1.3.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.7.22)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.11.7)
# Requirement already satisfied: url-normalize>=2.0 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for keap1**

# %%
# Target search for EGFR
target = new_client.target
target_query = target.search('EGFR')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references           organism  \
# 0                []       Homo sapiens
# 1                []       Homo sapiens
# 2                []       Mus musculus
# 3                []       Mus musculus
# 4                []       Homo sapiens
# 5                []       Homo sapiens
# 6                []       Homo sapiens
# 7                []       Homo sapiens
# 8                []       Homo sapiens
# 9                []       Mus musculus
# 10               []       Homo sapiens
# 11               []  Rattus norvegicus
# 12               []       Homo sapiens
# 13               []       Homo sapiens
# 14               []       Homo sapiens
# 15               []       Mus musculus
# 16               []       Homo sapiens
# 17               []       Homo sapiens
# 18               []       Homo sapiens
# 19               []       Homo sapiens
# 20               []       Homo sapiens
# 21               []       Homo sapiens
# 22               []       Homo sapiens
# 23               []       Homo sapiens
# 24               []       Homo sapiens
# 25               []       Homo sapiens
#
#                                             pref_name  score  \
# 0                                         EGFR/PPP1CA   17.0
# 1                                           CCN2-EGFR   17.0
# 2                    Epidermal growth factor receptor   15.0
# 3   Protein cereblon/Epidermal growth factor receptor   13.0
# 4                    Epidermal growth factor receptor   11.0
# 5   Protein cereblon/Epidermal growth factor receptor   11.0
# 6                    Epidermal growth factor receptor   10.0
# 7   MER intracellular domain/EGFR extracellular do...   10.0
# 8   von Hippel-Lindau disease tumor suppressor/Epi...   10.0
# 9   Protein cereblon/Epidermal growth factor receptor   10.0
# 10            Receptor tyrosine-protein kinase erbB-2    9.0
# 11            Receptor tyrosine-protein kinase erbB-2    9.0
# 12            Receptor tyrosine-protein kinase erbB-4    9.0
# 13            Receptor tyrosine-protein kinase erbB-3    9.0
# 14  Epidermal growth factor receptor and ErbB2 (HE...    9.0
# 15            Receptor tyrosine-protein kinase erbB-2    9.0
# 16                                          FASN/HER2    9.0
# 17                          ErbB-2/ErbB-3 heterodimer    9.0
# 18  Baculoviral IAP repeat-containing protein 2/Ep...    9.0
# 19  von Hippel-Lindau disease tumor suppressor/Rec...    9.0
# 20  Microtubule-associated protein 1 light chain 3...    9.0
# 21  Glucose-induced degradation protein 4 homolog/...    9.0
# 22  E3 ubiquitin-protein ligase Mdm2/Epidermal gro...    9.0
# 23               UBR/Epidermal growth factor receptor    9.0
# 24  Protein zyg-11 homolog B/Protein zer-1 homolog...    9.0
# 25  E3 ubiquitin-protein ligase RNF149/Epidermal g...    9.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL4523747
# 1                False    CHEMBL5465557
# 2                False       CHEMBL3608
# 3                False    CHEMBL6193842
# 4                False        CHEMBL203
# 5                False    CHEMBL4523680
# 6                False    CHEMBL2363049
# 7                False    CHEMBL3137284
# 8                False    CHEMBL4523998
# 9                False    CHEMBL6193841
# 10               False       CHEMBL1824
# 11               False       CHEMBL3848
# 12               False       CHEMBL3009
# 13               False       CHEMBL5838
# 14               False    CHEMBL2111431
# 15               False    CHEMBL2311234
# 16               False    CHEMBL4106134
# 17               False    CHEMBL4630723
# 18               False    CHEMBL4802031
# 19               False    CHEMBL5465227
# 20               False    CHEMBL6066839
# 21               False    CHEMBL6066845
# 22               False    CHEMBL6193792
# 23               False    CHEMBL6193830
# 24               False    CHEMBL6193837
# 25               False    CHEMBL6195769
#
#                                     target_components  \
# 0   [{'accession': 'P00533', 'component_descriptio...
# 1   [{'accession': 'P00533', 'component_descriptio...
# 2   [{'accession': 'Q01279', 'component_descriptio...
# 3   [{'accession': 'Q01279', 'component_descriptio...
# 4   [{'accession': 'P00533', 'component_descriptio...
# 5   [{'accession': 'P00533', 'component_descriptio...
# 6   [{'accession': 'P04626', 'component_descriptio...
# 7   [{'accession': 'P00533', 'component_descriptio...
# 8   [{'accession': 'P00533', 'component_descriptio...
# 9   [{'accession': 'P00533', 'component_descriptio...
# 10  [{'accession': 'P04626', 'component_descriptio...
# 11  [{'accession': 'P06494', 'component_descriptio...
# 12  [{'accession': 'Q15303', 'component_descriptio...
# 13  [{'accession': 'P21860', 'component_descriptio...
# 14  [{'accession': 'P04626', 'component_descriptio...
# 15  [{'accession': 'P70424', 'component_descriptio...
# 16  [{'accession': 'P04626', 'component_descriptio...
# 17  [{'accession': 'P04626', 'component_descriptio...
# 18  [{'accession': 'P00533', 'component_descriptio...
# 19  [{'accession': 'P04626', 'component_descriptio...
# 20  [{'accession': 'P00533', 'component_descriptio...
# 21  [{'accession': 'P00533', 'component_descriptio...
# 22  [{'accession': 'Q00987', 'component_descriptio...
# 23  [{'accession': 'P00533', 'component_descriptio...
# 24  [{'accession': 'P00533', 'component_descriptio...
# 25  [{'accession': 'P00533', 'component_descriptio...
#
#                     target_type  tax_id
# 0   PROTEIN-PROTEIN INTERACTION    9606
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2                SINGLE PROTEIN   10090
# 3   PROTEIN-PROTEIN INTERACTION   10090
# 4                SINGLE PROTEIN    9606
# 5   PROTEIN-PROTEIN INTERACTION    9606
# 6                PROTEIN FAMILY    9606
# 7              CHIMERIC PROTEIN    9606
# 8   PROTEIN-PROTEIN INTERACTION    9606
# 9   PROTEIN-PROTEIN INTERACTION   10090
# 10               SINGLE PROTEIN    9606
# 11               SINGLE PROTEIN   10116
# 12               SINGLE PROTEIN    9606
# 13               SINGLE PROTEIN    9606
# 14               PROTEIN FAMILY    9606
# 15               SINGLE PROTEIN   10090
# 16              PROTEIN COMPLEX    9606
# 17              PROTEIN COMPLEX    9606
# 18  PROTEIN-PROTEIN INTERACTION    9606
# 19  PROTEIN-PROTEIN INTERACTION    9606
# 20  PROTEIN-PROTEIN INTERACTION    9606
# 21  PROTEIN-PROTEIN INTERACTION    9606
# 22  PROTEIN-PROTEIN INTERACTION    9606
# 23  PROTEIN-PROTEIN INTERACTION    9606
# 24  PROTEIN-PROTEIN INTERACTION    9606
# 25  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL203'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32260                  []
# 1        None             None        32263                  []
# 2        None             None        32265                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 1    CHEMBL621151  Inhibition of autophosphorylation of human epi...
# 2    CHEMBL615325  Inhibition of ligand-induced proliferation in ...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          F                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
#
#   target_organism                  target_pref_name target_tax_id text_value  \
# 0    Homo sapiens  Epidermal growth factor receptor          9606       None
# 1    Homo sapiens  Epidermal growth factor receptor          9606       None
# 2    Homo sapiens  Epidermal growth factor receptor          9606       None
#
#    toid  type units    uo_units upper_value  value
# 0  None  IC50    uM  UO_0000065        None  0.041
# 1  None  IC50    uM  UO_0000065        None    0.3
# 2  None  IC50    uM  UO_0000065        None   7.82
#
# [3 rows x 47 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,modality,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,32260,[],CHEMBL674637,Inhibitory activity towards tyrosine phosphorylation for the epidermal growth factor-receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,"{'bei': '19.25', 'le': '0.37', 'lle': '2.94', 'sei': '8.93'}",,CHEMBL68920,,CHEMBL68920,7.39,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,41.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,0.041
# ,,32263,[],CHEMBL621151,Inhibition of autophosphorylation of human epidermal growth factor-receptor (EGF-R) expressed in A431 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,,CHEMBL68920,,CHEMBL68920,6.52,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,300.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,0.3
# ,,32265,[],CHEMBL615325,Inhibition of ligand-induced proliferation in human EGF-R Kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,,CHEMBL68920,,CHEMBL68920,5.11,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,7820.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,7.82
# ,,32267,[],CHEMBL674637,Inhibitory activity towards tyrosine phosphorylation for the epidermal growth factor-receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,"{'bei': '14.02', 'le': '0.27', 'lle': '3.16', 'sei': '6.03'}",,CHEMBL69960,,CHEMBL69960,6.77,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,170.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,0.17
# ,,32270,[],CHEMBL621151,Inhibition of autophosphorylation of human epidermal growth factor-receptor (EGF-R) expressed in A431 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,,CHEMBL69960,,CHEMBL69960,7.40,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,40.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,0.04
# ,,32272,[],CHEMBL615325,Inhibition of ligand-induced proliferation in human EGF-R Kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,,CHEMBL69960,,CHEMBL69960,6.36,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,440.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,0.44
# ,,32680,[],CHEMBL677833,In vitro inhibition of Epidermal growth factor receptor tyrosine kinase isolated from A431 (human carcinoma).,B,,,BAO_0000190,BAO_0000357,single protein format,CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12,,,CHEMBL1145114,J Med Chem,2003.0,"{'bei': '13.62', 'le': '0.25', 'lle': '0.26', 'sei': '6.40'}",,CHEMBL137635,,CHEMBL137635,5.03,0,http://www.openphacts.org/units/Nanomolar,262238,=,1,1,=,,IC50,nM,,9300.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,9.3
# ,,32770,[],CHEMBL674643,Inhibitory concentration of EGF dependent autophosphorylation of epidermal growth factor receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1124610,J Med Chem,1989.0,,,CHEMBL306988,,CHEMBL306988,,0,http://www.openphacts.org/units/Nanomolar,137177,=,1,1,=,,IC50,nM,,500000.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,500.0
# ,,32772,[],CHEMBL674643,Inhibitory concentration of EGF dependent autophosphorylation of epidermal growth factor receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(O)/C=C/c1ccc(O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1124610,J Med Chem,1989.0,,,CHEMBL66879,COUMARIC ACID,CHEMBL66879,,0,http://www.openphacts.org/units/Nanomolar,137215,=,1,1,=,,IC50,nM,,3000000.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor,9606,,,IC50,uM,UO_0000065,,3000.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()].reset_index(drop=True)
df2
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 25194  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 25195  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 25196  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 25197  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 25198  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id activity_properties assay_chembl_id  \
# 0            32260                  []    CHEMBL674637
# 1            32263                  []    CHEMBL621151
# 2            32265                  []    CHEMBL615325
# 3            32267                  []    CHEMBL674637
# 4            32270                  []    CHEMBL621151
# ...            ...                 ...             ...
# 25194     29313763                  []   CHEMBL6184534
# 25195     29313764                  []   CHEMBL6184534
# 25196     29313765                  []   CHEMBL6184534
# 25197     29313767                  []   CHEMBL6184534
# 25198     29313803                  []   CHEMBL6184543
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 25194       Inhibition of wildtype EGFR (unknown origin)          B
# 25195       Inhibition of wildtype EGFR (unknown origin)          B
# 25196       Inhibition of wildtype EGFR (unknown origin)          B
# 25197       Inhibition of wildtype EGFR (unknown origin)          B
# 25198                Inhibition of EGFR (unknown origin)          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                        None                   None  BAO_0000190  ...
# 1                        None                   None  BAO_0000190  ...
# 2                        None                   None  BAO_0000190  ...
# 3                        None                   None  BAO_0000190  ...
# 4                        None                   None  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 25194                    None                   None  BAO_0000190  ...
# 25195                    None                   None  BAO_0000190  ...
# 25196                    None                   None  BAO_0000190  ...
# 25197                    None                   None  BAO_0000190  ...
# 25198                    None                   None  BAO_0000190  ...
#
#       target_organism                  target_pref_name target_tax_id  \
# 0        Homo sapiens  Epidermal growth factor receptor          9606
# 1        Homo sapiens  Epidermal growth factor receptor          9606
# 2        Homo sapiens  Epidermal growth factor receptor          9606
# 3        Homo sapiens  Epidermal growth factor receptor          9606
# 4        Homo sapiens  Epidermal growth factor receptor          9606
# ...               ...                               ...           ...
# 25194    Homo sapiens  Epidermal growth factor receptor          9606
# 25195    Homo sapiens  Epidermal growth factor receptor          9606
# 25196    Homo sapiens  Epidermal growth factor receptor          9606
# 25197    Homo sapiens  Epidermal growth factor receptor          9606
# 25198    Homo sapiens  Epidermal growth factor receptor          9606
#
#       text_value  toid  type units    uo_units upper_value  value
# 0           None  None  IC50    uM  UO_0000065        None  0.041
# 1           None  None  IC50    uM  UO_0000065        None    0.3
# 2           None  None  IC50    uM  UO_0000065        None   7.82
# 3           None  None  IC50    uM  UO_0000065        None   0.17
# 4           None  None  IC50    uM  UO_0000065        None   0.04
# ...          ...   ...   ...   ...         ...         ...    ...
# 25194       None  None  IC50    nM  UO_0000065        None    9.8
# 25195       None  None  IC50    nM  UO_0000065        None  130.1
# 25196       None  None  IC50    nM  UO_0000065        None   4.81
# 25197       None  None  IC50    nM  UO_0000065        None  13.08
# 25198       None  None  IC50    nM  UO_0000065        None  0.025
#
# [25199 rows x 47 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 25194      CHEMBL6191667    O=C(CCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25195      CHEMBL6192203     O=C(CCCCCOc1cc2ncnc(Nc3ccccc3Cl)c2c2c1OCCO2)NO
# 25196      CHEMBL6191199   O=C(CCCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25197          CHEMBL939     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1
# 25198        CHEMBL29197                  COc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OC
#
#       bioactivity_class standard_value
# 0                active           41.0
# 1                active          300.0
# 2          intermediate         7820.0
# 3                active          170.0
# 4                active           40.0
# ...                 ...            ...
# 25194            active            9.8
# 25195            active          130.1
# 25196            active           4.81
# 25197            active          13.08
# 25198            active          0.025
#
# [25199 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 25194      CHEMBL6191667    O=C(CCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25195      CHEMBL6192203     O=C(CCCCCOc1cc2ncnc(Nc3ccccc3Cl)c2c2c1OCCO2)NO
# 25196      CHEMBL6191199   O=C(CCCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25197          CHEMBL939     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1
# 25198        CHEMBL29197                  COc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OC
#
#       standard_value
# 0               41.0
# 1              300.0
# 2             7820.0
# 3              170.0
# 4               40.0
# ...              ...
# 25194            9.8
# 25195          130.1
# 25196           4.81
# 25197          13.08
# 25198          0.025
#
# [25199 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 25194      CHEMBL6191667    O=C(CCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25195      CHEMBL6192203     O=C(CCCCCOc1cc2ncnc(Nc3ccccc3Cl)c2c2c1OCCO2)NO
# 25196      CHEMBL6191199   O=C(CCCCCOc1cc2ncnc(Nc3cccc(Cl)c3)c2c2c1OCCO2)NO
# 25197          CHEMBL939     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1
# 25198        CHEMBL29197                  COc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OC
#
#       standard_value             0
# 0               41.0        active
# 1              300.0        active
# 2             7820.0  intermediate
# 3              170.0        active
# 4               40.0        active
# ...              ...           ...
# 25194            9.8        active
# 25195          130.1        active
# 25196           4.81        active
# 25197          13.08        active
# 25198          0.025        active
#
# [25199 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 380
# -rw-r--r-- 1 root root 328475 Sep 13 17:11 bioactivity_data.csv
# -rw-r--r-- 1 root root  46039 Sep 13 17:18 bioactivity_preprocessed_data.csv
# drwx------ 5 root root   4096 Sep 13 17:12 gdrive
# drwxr-xr-x 1 root root   4096 Sep  4 13:25 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/EGFR"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/EGFR"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
